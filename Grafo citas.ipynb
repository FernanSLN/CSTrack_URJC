# %%
import pandas as pd
import re
from webweb import Web
import hashlib

# %%
df = pd.read_csv('Lynguo_def2.csv', sep= ';', error_bad_lines = False)

# %%
df= df.drop([78202], axis= 0)

# %%
df
# Out:
#       Borrado Favorito             Fecha   Fuente  \
# 0       false    false   30/09/2020 7:54  twitter
# 1       false    false   30/09/2020 8:10  twitter
# 2       false    false   30/09/2020 8:06  twitter
# 3       false    false   30/09/2020 7:57  twitter
# 4       false    false   30/09/2020 7:57  twitter
# ...       ...      ...               ...      ...
# 78197   false    false  03/12/2020 13:51  twitter
# 78198   false    false  03/12/2020 13:41  twitter
# 78199   false    false  03/12/2020 13:41  twitter
# 78200   false    false  03/12/2020 13:53  twitter
# 78201   false    false  03/12/2020 13:53  twitter
#
#                                                    Texto  \
# 0      RT @EcoEvoLab: Having seen two references to ?...
# 1      RT @OU_STEM: Our virtual ?Ask the Expert? seri...
# 2      RT @Macquarie_Uni: We?re delighted to see the ...
# 3      RT @EU_Aliens: Do you contribute to the ?Invas...
# 4      RT @EU_Aliens: Do you contribute to the ?Invas...
# ...                                                  ...
# 78197  #WeCantBreatheHereEither: as a virus attacks t...
# 78198  Great to see iAtlantic?s Science Council Membe...
# 78199  Great to see iAtlantic?s Science Council Membe...
# 78200  That?s great, the level is below 5 ugr/m3. Win...
# 78201  That?s great, the level is below 5 ugr/m3. Win...
#
#                                                   Enlace  \
# 0      http://twitter.com/EvoPhys/statuses/1311212816...
# 1      http://twitter.com/climate_col/statuses/131121...
# 2      http://twitter.com/ErturLevent/statuses/131121...
# 3      http://twitter.com/MiluElBarbaro/statuses/1311...
# 4      http://twitter.com/MiluElBarbaro/statuses/1311...
# ...                                                  ...
# 78197  http://twitter.com/chicocoradio/statuses/13344...
# 78198  http://twitter.com/iAtlanticEU/statuses/133449...
# 78199  http://twitter.com/iAtlanticEU/statuses/133449...
# 78200  http://twitter.com/Aalst_Waalre/statuses/13344...
# 78201  http://twitter.com/Aalst_Waalre/statuses/13344...
#
#                                   Marca        Usuario Oficial Opinion  \
# 0             Citizen science All World        EvoPhys   false   33,33
# 1             Citizen science All World    climate_col   false   66,67
# 2             Citizen science All World    ErturLevent   false     100
# 3                    Citizen science EU  MiluElBarbaro   false  -33,33
# 4             Citizen science All World  MiluElBarbaro   false  -33,33
# ...                                 ...            ...     ...     ...
# 78197         Citizen science All World   chicocoradio   false  -66,67
# 78198         Citizen science All World    iAtlanticEU   false      50
# 78199  Citizen science higher education    iAtlanticEU   false      50
# 78200         Citizen science All World   Aalst_Waalre   false      50
# 78201                Citizen science EU   Aalst_Waalre   false      50
#
#       Categoria Tags Impacto
# 0           NaN  NaN   42,17
# 1           NaN  NaN   41,66
# 2           NaN  NaN   34,59
# 3           NaN  NaN   31,73
# 4           NaN  NaN   31,73
# ...         ...  ...     ...
# 78197       NaN  NaN   36,53
# 78198       NaN  NaN   39,61
# 78199       NaN  NaN   39,61
# 78200       NaN  NaN   10,75
# 78201       NaN  NaN   10,75
#
# [78202 rows x 13 columns]

# %%
stopwords = ['#citizenscience', 'citizenscience', 'rt', 'citizen', 'science', 'citsci','cienciaciudadana']

# %%
dfMentions = df[['Usuario', 'Texto']].copy()

# %%
dfMentions= dfMentions.dropna()

# %%
dfEliminarRTs = dfMentions[dfMentions['Texto'].str.match('RT ')]

# %%
dfMentions = dfMentions[dfMentions['Texto'].str.contains('@.')]

mentionsSubset = dfMentions[['Usuario', 'Texto']]

mentionsList = [list(x) for x in mentionsSubset.to_numpy()]
mentionEdges = []
for row in mentionsList:
    match = re.search('@(\w+)', row[1])
    if match:
        match = match.group(1)
        row[1] = hashlib.md5(match.encode()).hexdigest()  
        mentionEdges.append(row)

# %%
web = Web(mentionEdges)
web.display.gravity = 1
web.show()
